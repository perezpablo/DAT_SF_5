# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/titanic-train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
#How many passengers are in our passenger list? 
#Answer: 891

data.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
#What is the overall survival rate?
#342/891=38%
survival=data[data.Survived>0]
survival.count()
# Out:
# PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            290
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Cabin          136
# Embarked       340
# dtype: int64

# %%
#How many male passengers were onboard?
#577
df = pd.DataFrame(data)
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Sex
# female          314       314     314   314  314  261    314    314     314
# male            577       577     577   577  577  453    577    577     577
#
#         Fare  Cabin  Embarked
# Sex
# female   314     97       312
# male     577    107       577
#
# [2 rows x 12 columns]

# %%
#How many female passengers were onboard?
#314
df = pd.DataFrame(data)
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Sex
# female          314       314     314   314  314  261    314    314     314
# male            577       577     577   577  577  453    577    577     577
#
#         Fare  Cabin  Embarked
# Sex
# female   314     97       312
# male     577    107       577
#
# [2 rows x 12 columns]

# %%
#What is the overall survival rate of male passengers?
#109/577=18%
df = pd.DataFrame(data)
df.groupby('Sex').sum()
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865
#
# [2 rows x 7 columns]

# %%
#What is the overall survival rate of female passengers?
#233/314=74%
df = pd.DataFrame(data)
df.groupby('Sex').sum()
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865
#
# [2 rows x 7 columns]

# %%
#What is the average age of all passengers onboard? ~30 years old
#a. How did you calculate this average age? data.mean()
#b. Did you encounter any problems with this calculation? no 
#c. If so, how did you address any problems? 

data.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
#What is the average age of passengers who survived? 28 years old
df = pd.DataFrame(data)
df.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408
#
# [2 rows x 6 columns]

# %%
#What is the average age of passengers who did not survive? ~31 years old
df = pd.DataFrame(data)
df.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408
#
# [2 rows x 6 columns]

# %%
#At this (early) point in our analysis, what might you infer about any patterns you are seeing? That if you were a 31 year old male, you were unlikely to live

# %%
#How many passengers are in each of the three classes of service (e.g. First, Second, Third?) 216 in first class, 184 in second class, and 491 in third class
df = pd.DataFrame(data)
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Pclass
# 1               216       216     216   216  216  186    216    216     216
# 2               184       184     184   184  184  173    184    184     184
# 3               491       491     491   491  491  355    491    491     491
#
#         Fare  Cabin  Embarked
# Pclass
# 1        216    176       214
# 2        184     16       184
# 3        491     12       491
#
# [3 rows x 12 columns]

# %%
#What is the survival rate for passengers in each of the three classes of service?
#first class [136/891 = 15%], second class [87/891 = 10%], third class = [119/891 = 13%]

df = pd.DataFrame(data)
df.groupby('Pclass').sum()
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951
#
# [3 rows x 6 columns]

# %%
#Continuing with 10, what else might you conclude? That if you were a 30 year old make in second class, you were likely to have sinked with the Titanic

# %%
#Last, if we were to build a predictive model, which features in the data do you think we should include in the model and which can we leave out? Why?
#For a predictive model I would include survival, age, sex, class, port, cabin, siblings/spouse, and children/parents - these items are important because they seem like they would have a direct correlation with survival rate
#Name, Ticket Number I would leave out bc I would assume they would not be correlated with the survival - just because you are named Michael doesn't mean you have a better chance of suriving and ticket numbers are randomly generated
